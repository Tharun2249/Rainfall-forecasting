# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import pdist


# Load the data into a pandas dataframe
data = pd.read_csv('file.csv')

# Combine the year and month columns into a single datetime column
data['date'] = pd.to_datetime(data['year'].astype(str) + '-' + data['Month'], format='%Y-%B')

# Drop the original year and month columns
data = data.drop(['year', 'Month'], axis=1)

# Divide the date into quarters and add the quarter column
data['quarter'] = data['date'].dt.quarter
print(data)
# Select the columns for temperature, rainfall, GHG, and CH4
columns = ['Temperature', 'Rainfall', 'ghg', 'ch4']

# Fill in missing values with their respective mean value for that column
for col in columns:
    data[col] = data[col].fillna(data[col].mean())

# Divide the year into quarters and add the quarter column
data['Quarter'] = data['date'].dt.quarter

# Create a dictionary to store the correlation matrices for each quarter
corr_dict = {}

# Loop through each quarter and calculate the correlation matrix for temperature, rainfall, GHG, and CH4
for quarter in range(1, 5):
    # Select the data for the current quarter
    quarter_data = data[data['Quarter'] == quarter]

    # Select the columns for temperature, rainfall, GHG, and CH4
    quarter_data = quarter_data[columns]

    # Calculate the correlation matrix
    corr_matrix = quarter_data.corr()

    # Store the correlation matrix in the dictionary
    corr_dict[f'Q{quarter}'] = corr_matrix

# Plot the correlation matrices as lower triangle heatmaps
for i, quarter in enumerate(corr_dict.keys()):
    # Create a mask to plot only the lower triangle of the heatmap
    mask = np.zeros_like(corr_dict[quarter], dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True


    # Plot the heatmap with diagonal values included
    plt.subplot(2, 2, i+1)
    sns.heatmap(corr_dict[quarter], annot=True, cmap='coolwarm', mask=mask,
                xticklabels=['Temperature', 'Rainfall', 'GHG', 'CH4'],
                yticklabels=['Temperature', 'Rainfall', 'GHG', 'CH4'])

    # Set the title and axis labels
    plt.title(f'Correlation Matrix for {quarter} from 1901-2016')
    plt.xlabel('Variables')
    plt.ylabel('Variables')

# Adjust the spacing between the subplots
plt.subplots_adjust(hspace=0.5, wspace=0.3)

# Show the plot
plt.show()
# Out:
#       Temperature  Rainfall         ghg         ch4       date  quarter
# 0         7.72768  40.42580   16.900000   12.325000 1901-01-01        1
# 1         8.93600  12.30220   16.908333   12.329167 1901-02-01        1
# 2        16.96320  25.51190   16.916667   12.333333 1901-03-01        1
# 3        21.27410  14.29420   16.925000   12.337500 1901-04-01        2
# 4        26.04970  38.30460   16.933333   12.341667 1901-05-01        2
# ...           ...       ...         ...         ...        ...      ...
# 1387     27.63320  60.60610  183.666667  125.479167 2016-08-01        3
# 1388     26.71790  13.76940  184.333333  125.833333 2016-09-01        3
# 1389     22.39820   1.07552  185.000000  126.187500 2016-10-01        4
# 1390     15.76720   2.88480  185.666667  126.541667 2016-11-01        4
# 1391     12.87630   7.82298  186.333333  126.895833 2016-12-01        4
#
# [1392 rows x 6 columns]
# <ipython-input-6-fb463b0db850>:55: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr_dict[quarter], dtype=np.bool)

# %%
# Drop the original year and month columns
data = data.drop(['date', 'Quarter','quarter'], axis=1)
print(data)
# Out:
#       Temperature  Rainfall         ghg         ch4
# 0         7.72768  40.42580   16.900000   12.325000
# 1         8.93600  12.30220   16.908333   12.329167
# 2        16.96320  25.51190   16.916667   12.333333
# 3        21.27410  14.29420   16.925000   12.337500
# 4        26.04970  38.30460   16.933333   12.341667
# ...           ...       ...         ...         ...
# 1387     27.63320  60.60610  183.666667  125.479167
# 1388     26.71790  13.76940  184.333333  125.833333
# 1389     22.39820   1.07552  185.000000  126.187500
# 1390     15.76720   2.88480  185.666667  126.541667
# 1391     12.87630   7.82298  186.333333  126.895833
#
# [1392 rows x 4 columns]

# %%
# Split the data into training and testing sets
train_data = data.iloc[:int(len(data)*0.8), :]
test_data = data.iloc[int(len(data)*0.8):, :]

# Split the training data into training and validation sets
val_data = train_data.iloc[int(len(train_data)*0.8):, :]
train_data = train_data.iloc[:int(len(train_data)*0.8), :]

# Scale the data
scaler = MinMaxScaler()
train_data = scaler.fit_transform(train_data)
val_data = scaler.transform(val_data)
test_data = scaler.transform(test_data)

def create_dataset(data, target, time_steps):
    X = []
    y = []
    for i in range(len(data)-time_steps):
        X.append(data[i:i+time_steps])
        y.append(target[i+time_steps])
    return np.array(X), np.array(y)


# Define the time steps and the number of features
time_steps = 5
num_features = train_data.shape[1]

# Create the training dataset
X_train, y_train = [], []
for i in range(time_steps, len(train_data)):
    X_train.append(train_data[i-time_steps:i])
    y_train.append(train_data[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Create the testing dataset
X_test, y_test = [], []
for i in range(time_steps, len(test_data)):
    X_test.append(test_data[i-time_steps:i])
    y_test.append(test_data[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

# Print the shapes of the datasets
print("Training set shape: ", X_train.shape, y_train.shape)
print("Validation set shape: ", val_data.shape)
print("Testing set shape: ", X_test.shape, y_test.shape)
# Out:
# Training set shape:  (885, 5, 4) (885,)
# Validation set shape:  (223, 4)
# Testing set shape:  (274, 5, 4) (274,)

# %%
# Create the model
model = Sequential()
model.add(GRU(256, return_sequences=True, input_shape=(None, num_features)))
model.add(Dropout(0.5))
model.add(GRU(128, return_sequences=True))
model.add(Dropout(0.5))
model.add(GRU(64, return_sequences=True))
model.add(Dropout(0.5))
model.add(GRU(32))
model.add(Dropout(0.5))
model.add(Dense(units=1))

# Print the model summary
print(model.summary())

# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error')

# Train the model
history = model.fit(X_train, y_train, epochs=400, batch_size=64, validation_data=(X_test, y_test), verbose=1)

# Predict the test data
y_pred = model.predict(X_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, None, 256)         201216
#
#  dropout (Dropout)           (None, None, 256)         0
#
#  gru_1 (GRU)                 (None, None, 128)         148224
#
#  dropout_1 (Dropout)         (None, None, 128)         0
#
#  gru_2 (GRU)                 (None, None, 64)          37248
#
#  dropout_2 (Dropout)         (None, None, 64)          0
#
#  gru_3 (GRU)                 (None, 32)                9408
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 396,129
# Trainable params: 396,129
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/400
# 14/14 [==============================] - 11s 159ms/step - loss: 0.3612 - val_loss: 0.2671
# Epoch 2/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.3031 - val_loss: 0.2357
# Epoch 3/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.2545 - val_loss: 0.4532
# Epoch 4/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.2229 - val_loss: 0.1693
# Epoch 5/400
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1856 - val_loss: 0.1361
# Epoch 6/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1615 - val_loss: 0.1687
# Epoch 7/400
# 14/14 [==============================] - 1s 51ms/step - loss: 0.1425 - val_loss: 0.2321
# Epoch 8/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1397 - val_loss: 0.1330
# Epoch 9/400
# 14/14 [==============================] - 1s 80ms/step - loss: 0.1431 - val_loss: 0.0889
# Epoch 10/400
# 14/14 [==============================] - 1s 95ms/step - loss: 0.1253 - val_loss: 0.1742
# Epoch 11/400
# 14/14 [==============================] - 1s 74ms/step - loss: 0.1196 - val_loss: 0.1828
# Epoch 12/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1263 - val_loss: 0.1024
# Epoch 13/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.1225 - val_loss: 0.1129
# Epoch 14/400
# 14/14 [==============================] - 1s 83ms/step - loss: 0.1260 - val_loss: 0.2062
# Epoch 15/400
# 14/14 [==============================] - 1s 93ms/step - loss: 0.1234 - val_loss: 0.1038
# Epoch 16/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1188 - val_loss: 0.1320
# Epoch 17/400
# 14/14 [==============================] - 1s 84ms/step - loss: 0.1234 - val_loss: 0.0767
# Epoch 18/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1189 - val_loss: 0.1114
# Epoch 19/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.1172 - val_loss: 0.1130
# Epoch 20/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1155 - val_loss: 0.1055
# Epoch 21/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1145 - val_loss: 0.0597
# Epoch 22/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.1191 - val_loss: 0.0841
# Epoch 23/400
# 14/14 [==============================] - 1s 96ms/step - loss: 0.1138 - val_loss: 0.0963
# Epoch 24/400
# 14/14 [==============================] - 1s 99ms/step - loss: 0.1052 - val_loss: 0.0756
# Epoch 25/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1083 - val_loss: 0.1095
# Epoch 26/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1064 - val_loss: 0.1103
# Epoch 27/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1080 - val_loss: 0.0773
# Epoch 28/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1070 - val_loss: 0.0803
# Epoch 29/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1029 - val_loss: 0.0852
# Epoch 30/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1026 - val_loss: 0.0879
# Epoch 31/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1048 - val_loss: 0.1124
# Epoch 32/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.1010 - val_loss: 0.0666
# Epoch 33/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0949 - val_loss: 0.0943
# Epoch 34/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.1002 - val_loss: 0.0934
# Epoch 35/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0958 - val_loss: 0.0859
# Epoch 36/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0982 - val_loss: 0.0817
# Epoch 37/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0966 - val_loss: 0.0800
# Epoch 38/400
# 14/14 [==============================] - 2s 123ms/step - loss: 0.0885 - val_loss: 0.0807
# Epoch 39/400
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0995 - val_loss: 0.0631
# Epoch 40/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.1005 - val_loss: 0.0782
# Epoch 41/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0968 - val_loss: 0.1124
# Epoch 42/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0951 - val_loss: 0.1728
# Epoch 43/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0925 - val_loss: 0.0637
# Epoch 44/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0910 - val_loss: 0.0658
# Epoch 45/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0910 - val_loss: 0.0932
# Epoch 46/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0836 - val_loss: 0.0494
# Epoch 47/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0875 - val_loss: 0.0592
# Epoch 48/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0900 - val_loss: 0.1321
# Epoch 49/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0924 - val_loss: 0.0526
# Epoch 50/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0902 - val_loss: 0.0507
# Epoch 51/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0835 - val_loss: 0.0993
# Epoch 52/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0845 - val_loss: 0.0481
# Epoch 53/400
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0896 - val_loss: 0.0502
# Epoch 54/400
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0856 - val_loss: 0.0599
# Epoch 55/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0893 - val_loss: 0.0521
# Epoch 56/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0882 - val_loss: 0.0508
# Epoch 57/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0923 - val_loss: 0.0652
# Epoch 58/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0892 - val_loss: 0.0604
# Epoch 59/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0884 - val_loss: 0.1099
# Epoch 60/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0842 - val_loss: 0.0469
# Epoch 61/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0804 - val_loss: 0.0475
# Epoch 62/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0819 - val_loss: 0.1032
# Epoch 63/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0836 - val_loss: 0.0478
# Epoch 64/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0807 - val_loss: 0.0450
# Epoch 65/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0818 - val_loss: 0.0585
# Epoch 66/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0820 - val_loss: 0.0460
# Epoch 67/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0841 - val_loss: 0.0805
# Epoch 68/400
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0830 - val_loss: 0.0746
# Epoch 69/400
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0820 - val_loss: 0.0629
# Epoch 70/400
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0847 - val_loss: 0.0946
# Epoch 71/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0837 - val_loss: 0.0589
# Epoch 72/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0827 - val_loss: 0.0641
# Epoch 73/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0810 - val_loss: 0.0968
# Epoch 74/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0820 - val_loss: 0.0497
# Epoch 75/400
# 14/14 [==============================] - 1s 51ms/step - loss: 0.0787 - val_loss: 0.1053
# Epoch 76/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0796 - val_loss: 0.0696
# Epoch 77/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0779 - val_loss: 0.0932
# Epoch 78/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0781 - val_loss: 0.0665
# Epoch 79/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0798 - val_loss: 0.0802
# Epoch 80/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0799 - val_loss: 0.0829
# Epoch 81/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0776 - val_loss: 0.0394
# Epoch 82/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0768 - val_loss: 0.0695
# Epoch 83/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0780 - val_loss: 0.0844
# Epoch 84/400
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0796 - val_loss: 0.0625
# Epoch 85/400
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0803 - val_loss: 0.0720
# Epoch 86/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0750 - val_loss: 0.0676
# Epoch 87/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0773 - val_loss: 0.0637
# Epoch 88/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0755 - val_loss: 0.0698
# Epoch 89/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0763 - val_loss: 0.1257
# Epoch 90/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0735 - val_loss: 0.0829
# Epoch 91/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0767 - val_loss: 0.0488
# Epoch 92/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0750 - val_loss: 0.0531
# Epoch 93/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0766 - val_loss: 0.0494
# Epoch 94/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0746 - val_loss: 0.1051
# Epoch 95/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0724 - val_loss: 0.0487
# Epoch 96/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0750 - val_loss: 0.0412
# Epoch 97/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0735 - val_loss: 0.0665
# Epoch 98/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0745 - val_loss: 0.0621
# Epoch 99/400
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0760 - val_loss: 0.0553
# Epoch 100/400
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0729 - val_loss: 0.0462
# Epoch 101/400
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0747 - val_loss: 0.0710
# Epoch 102/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0768 - val_loss: 0.0708
# Epoch 103/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0730 - val_loss: 0.0562
# Epoch 104/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0718 - val_loss: 0.0886
# Epoch 105/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0737 - val_loss: 0.0484
# Epoch 106/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0719 - val_loss: 0.0601
# Epoch 107/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0719 - val_loss: 0.0441
# Epoch 108/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0742 - val_loss: 0.0581
# Epoch 109/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0704 - val_loss: 0.0640
# Epoch 110/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0714 - val_loss: 0.0595
# Epoch 111/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0735 - val_loss: 0.0619
# Epoch 112/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0740 - val_loss: 0.0464
# Epoch 113/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0701 - val_loss: 0.0409
# Epoch 114/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0714 - val_loss: 0.0582
# Epoch 115/400
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0699 - val_loss: 0.0522
# Epoch 116/400
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0683 - val_loss: 0.0579
# Epoch 117/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0718 - val_loss: 0.0615
# Epoch 118/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0695 - val_loss: 0.0931
# Epoch 119/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0701 - val_loss: 0.0642
# Epoch 120/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0692 - val_loss: 0.0548
# Epoch 121/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0730 - val_loss: 0.0566
# Epoch 122/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0704 - val_loss: 0.0617
# Epoch 123/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0706 - val_loss: 0.0632
# Epoch 124/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0746 - val_loss: 0.0597
# Epoch 125/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0719 - val_loss: 0.0752
# Epoch 126/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0690 - val_loss: 0.1020
# Epoch 127/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0685 - val_loss: 0.0635
# Epoch 128/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0696 - val_loss: 0.0826
# Epoch 129/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0707 - val_loss: 0.0628
# Epoch 130/400
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0698 - val_loss: 0.0598
# Epoch 131/400
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0662 - val_loss: 0.0493
# Epoch 132/400
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0678 - val_loss: 0.0781
# Epoch 133/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0668 - val_loss: 0.0555
# Epoch 134/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0698 - val_loss: 0.0654
# Epoch 135/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0690 - val_loss: 0.0631
# Epoch 136/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0672 - val_loss: 0.0666
# Epoch 137/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0673 - val_loss: 0.0680
# Epoch 138/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0676 - val_loss: 0.0697
# Epoch 139/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0657 - val_loss: 0.0470
# Epoch 140/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0676 - val_loss: 0.0518
# Epoch 141/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0666 - val_loss: 0.0556
# Epoch 142/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0662 - val_loss: 0.0497
# Epoch 143/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0676 - val_loss: 0.0448
# Epoch 144/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0670 - val_loss: 0.0617
# Epoch 145/400
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0696 - val_loss: 0.0483
# Epoch 146/400
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0660 - val_loss: 0.0533
# Epoch 147/400
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0678 - val_loss: 0.0488
# Epoch 148/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0650 - val_loss: 0.0499
# Epoch 149/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0668 - val_loss: 0.0527
# Epoch 150/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0651 - val_loss: 0.0596
# Epoch 151/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0654 - val_loss: 0.0413
# Epoch 152/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0669 - val_loss: 0.0493
# Epoch 153/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0642 - val_loss: 0.0460
# Epoch 154/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0661 - val_loss: 0.0479
# Epoch 155/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0669 - val_loss: 0.0513
# Epoch 156/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0658 - val_loss: 0.0512
# Epoch 157/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0640 - val_loss: 0.0553
# Epoch 158/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0634 - val_loss: 0.0462
# Epoch 159/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0679 - val_loss: 0.0540
# Epoch 160/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0650 - val_loss: 0.0627
# Epoch 161/400
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0653 - val_loss: 0.0477
# Epoch 162/400
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0643 - val_loss: 0.0720
# Epoch 163/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0644 - val_loss: 0.0575
# Epoch 164/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0662 - val_loss: 0.0687
# Epoch 165/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0687 - val_loss: 0.0497
# Epoch 166/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0691 - val_loss: 0.0604
# Epoch 167/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0689 - val_loss: 0.0466
# Epoch 168/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0635 - val_loss: 0.0805
# Epoch 169/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0643 - val_loss: 0.0565
# Epoch 170/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0614 - val_loss: 0.0644
# Epoch 171/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0678 - val_loss: 0.0528
# Epoch 172/400
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0640 - val_loss: 0.0569
# Epoch 173/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0646 - val_loss: 0.0444
# Epoch 174/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0643 - val_loss: 0.0512
# Epoch 175/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0626 - val_loss: 0.0586
# Epoch 176/400
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0677 - val_loss: 0.0642
# Epoch 177/400
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0641 - val_loss: 0.0589
# Epoch 178/400
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0643 - val_loss: 0.0633
# Epoch 179/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0640 - val_loss: 0.0531
# Epoch 180/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0634 - val_loss: 0.0426
# Epoch 181/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0618 - val_loss: 0.0438
# Epoch 182/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0638 - val_loss: 0.0440
# Epoch 183/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0674 - val_loss: 0.0442
# Epoch 184/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0649 - val_loss: 0.0564
# Epoch 185/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0656 - val_loss: 0.0511
# Epoch 186/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0649 - val_loss: 0.0545
# Epoch 187/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0638 - val_loss: 0.0491
# Epoch 188/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0645 - val_loss: 0.0511
# Epoch 189/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0658 - val_loss: 0.0456
# Epoch 190/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0594 - val_loss: 0.0474
# Epoch 191/400
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0611 - val_loss: 0.0744
# Epoch 192/400
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0614 - val_loss: 0.0423
# Epoch 193/400
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0624 - val_loss: 0.0490
# Epoch 194/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0627 - val_loss: 0.0469
# Epoch 195/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0658 - val_loss: 0.0431
# Epoch 196/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0628 - val_loss: 0.0569
# Epoch 197/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0611 - val_loss: 0.0497
# Epoch 198/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0667 - val_loss: 0.0578
# Epoch 199/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0590 - val_loss: 0.0677
# Epoch 200/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0626 - val_loss: 0.0362
# Epoch 201/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0642 - val_loss: 0.0472
# Epoch 202/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0662 - val_loss: 0.0406
# Epoch 203/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0613 - val_loss: 0.0391
# Epoch 204/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0633 - val_loss: 0.0499
# Epoch 205/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0616 - val_loss: 0.0439
# Epoch 206/400
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0637 - val_loss: 0.0382
# Epoch 207/400
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0642 - val_loss: 0.0401
# Epoch 208/400
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0631 - val_loss: 0.0643
# Epoch 209/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0637 - val_loss: 0.0711
# Epoch 210/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0657 - val_loss: 0.0512
# Epoch 211/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0647 - val_loss: 0.0528
# Epoch 212/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0623 - val_loss: 0.0430
# Epoch 213/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0661 - val_loss: 0.0469
# Epoch 214/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0632 - val_loss: 0.0369
# Epoch 215/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0610 - val_loss: 0.0494
# Epoch 216/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0626 - val_loss: 0.0503
# Epoch 217/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0621 - val_loss: 0.0417
# Epoch 218/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0633 - val_loss: 0.0390
# Epoch 219/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0629 - val_loss: 0.0369
# Epoch 220/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0610 - val_loss: 0.0401
# Epoch 221/400
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0633 - val_loss: 0.0648
# Epoch 222/400
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0622 - val_loss: 0.0504
# Epoch 223/400
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0633 - val_loss: 0.0476
# Epoch 224/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0621 - val_loss: 0.0421
# Epoch 225/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0615 - val_loss: 0.0412
# Epoch 226/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0631 - val_loss: 0.0421
# Epoch 227/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0639 - val_loss: 0.0355
# Epoch 228/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0621 - val_loss: 0.0363
# Epoch 229/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0646 - val_loss: 0.0384
# Epoch 230/400
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0611 - val_loss: 0.0415
# Epoch 231/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0653 - val_loss: 0.0380
# Epoch 232/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0637 - val_loss: 0.0403
# Epoch 233/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0644 - val_loss: 0.0362
# Epoch 234/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0600 - val_loss: 0.0637
# Epoch 235/400
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0638 - val_loss: 0.0398
# Epoch 236/400
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0602 - val_loss: 0.0356
# Epoch 237/400
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0595 - val_loss: 0.0413
# Epoch 238/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0626 - val_loss: 0.0502
# Epoch 239/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0611 - val_loss: 0.0542
# Epoch 240/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0607 - val_loss: 0.0375
# Epoch 241/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0618 - val_loss: 0.0396
# Epoch 242/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0588 - val_loss: 0.0593
# Epoch 243/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0617 - val_loss: 0.0494
# Epoch 244/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0615 - val_loss: 0.0408
# Epoch 245/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0611 - val_loss: 0.0426
# Epoch 246/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0614 - val_loss: 0.0545
# Epoch 247/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0636 - val_loss: 0.0490
# Epoch 248/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0604 - val_loss: 0.0536
# Epoch 249/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0621 - val_loss: 0.0614
# Epoch 250/400
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0621 - val_loss: 0.0353
# Epoch 251/400
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0602 - val_loss: 0.0379
# Epoch 252/400
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0599 - val_loss: 0.0388
# Epoch 253/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0622 - val_loss: 0.0451
# Epoch 254/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0640 - val_loss: 0.0401
# Epoch 255/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0620 - val_loss: 0.0363
# Epoch 256/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0620 - val_loss: 0.0375
# Epoch 257/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0577 - val_loss: 0.0520
# Epoch 258/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0615 - val_loss: 0.0584
# Epoch 259/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0629 - val_loss: 0.0587
# Epoch 260/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0614 - val_loss: 0.0420
# Epoch 261/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0599 - val_loss: 0.0378
# Epoch 262/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0595 - val_loss: 0.0432
# Epoch 263/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0584 - val_loss: 0.0360
# Epoch 264/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0641 - val_loss: 0.0405
# Epoch 265/400
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0598 - val_loss: 0.0403
# Epoch 266/400
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0604 - val_loss: 0.0447
# Epoch 267/400
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0632 - val_loss: 0.0525
# Epoch 268/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0606 - val_loss: 0.0506
# Epoch 269/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0632 - val_loss: 0.0463
# Epoch 270/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0592 - val_loss: 0.0420
# Epoch 271/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0628 - val_loss: 0.0506
# Epoch 272/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0609 - val_loss: 0.0551
# Epoch 273/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0609 - val_loss: 0.0478
# Epoch 274/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0615 - val_loss: 0.0399
# Epoch 275/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0607 - val_loss: 0.0411
# Epoch 276/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0606 - val_loss: 0.0414
# Epoch 277/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0614 - val_loss: 0.0368
# Epoch 278/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0604 - val_loss: 0.0468
# Epoch 279/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0606 - val_loss: 0.0365
# Epoch 280/400
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0592 - val_loss: 0.0378
# Epoch 281/400
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0592 - val_loss: 0.0452
# Epoch 282/400
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0613 - val_loss: 0.0498
# Epoch 283/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0617 - val_loss: 0.0487
# Epoch 284/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0603 - val_loss: 0.0416
# Epoch 285/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0593 - val_loss: 0.0393
# Epoch 286/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0619 - val_loss: 0.0388
# Epoch 287/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0599 - val_loss: 0.0536
# Epoch 288/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0609 - val_loss: 0.0404
# Epoch 289/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0582 - val_loss: 0.0393
# Epoch 290/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0621 - val_loss: 0.0349
# Epoch 291/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0617 - val_loss: 0.0548
# Epoch 292/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0601 - val_loss: 0.0405
# Epoch 293/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0623 - val_loss: 0.0378
# Epoch 294/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0604 - val_loss: 0.0389
# Epoch 295/400
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0607 - val_loss: 0.0424
# Epoch 296/400
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0584 - val_loss: 0.0444
# Epoch 297/400
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0604 - val_loss: 0.0401
# Epoch 298/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0588 - val_loss: 0.0398
# Epoch 299/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0604 - val_loss: 0.0457
# Epoch 300/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0620 - val_loss: 0.0498
# Epoch 301/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0607 - val_loss: 0.0473
# Epoch 302/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0603 - val_loss: 0.0417
# Epoch 303/400
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0598 - val_loss: 0.0359
# Epoch 304/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0603 - val_loss: 0.0395
# Epoch 305/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0602 - val_loss: 0.0608
# Epoch 306/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0600 - val_loss: 0.0564
# Epoch 307/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0582 - val_loss: 0.0455
# Epoch 308/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0614 - val_loss: 0.0401
# Epoch 309/400
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0608 - val_loss: 0.0412
# Epoch 310/400
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0597 - val_loss: 0.0358
# Epoch 311/400
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0565 - val_loss: 0.0358
# Epoch 312/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0628 - val_loss: 0.0412
# Epoch 313/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0624 - val_loss: 0.0360
# Epoch 314/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0606 - val_loss: 0.0358
# Epoch 315/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0601 - val_loss: 0.0404
# Epoch 316/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0587 - val_loss: 0.0463
# Epoch 317/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0601 - val_loss: 0.0647
# Epoch 318/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0595 - val_loss: 0.0527
# Epoch 319/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0621 - val_loss: 0.0473
# Epoch 320/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0634 - val_loss: 0.0558
# Epoch 321/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0624 - val_loss: 0.0480
# Epoch 322/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0585 - val_loss: 0.0512
# Epoch 323/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0610 - val_loss: 0.0461
# Epoch 324/400
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0591 - val_loss: 0.0347
# Epoch 325/400
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0595 - val_loss: 0.0361
# Epoch 326/400
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0623 - val_loss: 0.0426
# Epoch 327/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0612 - val_loss: 0.0448
# Epoch 328/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0613 - val_loss: 0.0437
# Epoch 329/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0611 - val_loss: 0.0406
# Epoch 330/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0628 - val_loss: 0.0372
# Epoch 331/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0604 - val_loss: 0.0494
# Epoch 332/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0600 - val_loss: 0.0481
# Epoch 333/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0595 - val_loss: 0.0377
# Epoch 334/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0580 - val_loss: 0.0354
# Epoch 335/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0637 - val_loss: 0.0594
# Epoch 336/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0608 - val_loss: 0.0468
# Epoch 337/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0600 - val_loss: 0.0462
# Epoch 338/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0584 - val_loss: 0.0412
# Epoch 339/400
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0585 - val_loss: 0.0396
# Epoch 340/400
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0604 - val_loss: 0.0511
# Epoch 341/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0589 - val_loss: 0.0619
# Epoch 342/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0609 - val_loss: 0.0408
# Epoch 343/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0578 - val_loss: 0.0499
# Epoch 344/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0621 - val_loss: 0.0355
# Epoch 345/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0612 - val_loss: 0.0376
# Epoch 346/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0606 - val_loss: 0.0404
# Epoch 347/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0600 - val_loss: 0.0465
# Epoch 348/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0639 - val_loss: 0.0389
# Epoch 349/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0631 - val_loss: 0.0377
# Epoch 350/400
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0615 - val_loss: 0.0429
# Epoch 351/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0599 - val_loss: 0.0360
# Epoch 352/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0624 - val_loss: 0.0433
# Epoch 353/400
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0624 - val_loss: 0.0355
# Epoch 354/400
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0575 - val_loss: 0.0513
# Epoch 355/400
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0602 - val_loss: 0.0569
# Epoch 356/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0619 - val_loss: 0.0615
# Epoch 357/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0571 - val_loss: 0.0794
# Epoch 358/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0585 - val_loss: 0.0626
# Epoch 359/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0590 - val_loss: 0.0369
# Epoch 360/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0567 - val_loss: 0.0393
# Epoch 361/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0603 - val_loss: 0.0372
# Epoch 362/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0595 - val_loss: 0.0396
# Epoch 363/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0586 - val_loss: 0.0535
# Epoch 364/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0590 - val_loss: 0.0590
# Epoch 365/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0585 - val_loss: 0.0432
# Epoch 366/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0615 - val_loss: 0.0437
# Epoch 367/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0616 - val_loss: 0.0407
# Epoch 368/400
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0590 - val_loss: 0.0434
# Epoch 369/400
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0588 - val_loss: 0.0485
# Epoch 370/400
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0593 - val_loss: 0.0622
# Epoch 371/400
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0588 - val_loss: 0.0559
# Epoch 372/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0592 - val_loss: 0.0438
# Epoch 373/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0586 - val_loss: 0.0455
# Epoch 374/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0615 - val_loss: 0.0515
# Epoch 375/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0585 - val_loss: 0.0528
# Epoch 376/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0615 - val_loss: 0.0415
# Epoch 377/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0588 - val_loss: 0.0413
# Epoch 378/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0607 - val_loss: 0.0488
# Epoch 379/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0632 - val_loss: 0.0529
# Epoch 380/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0576 - val_loss: 0.0480
# Epoch 381/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0614 - val_loss: 0.0361
# Epoch 382/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0581 - val_loss: 0.0498
# Epoch 383/400
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0603 - val_loss: 0.0433
# Epoch 384/400
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0592 - val_loss: 0.0493
# Epoch 385/400
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0576 - val_loss: 0.0467
# Epoch 386/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0609 - val_loss: 0.0471
# Epoch 387/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0608 - val_loss: 0.0452
# Epoch 388/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0594 - val_loss: 0.0454
# Epoch 389/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0624 - val_loss: 0.0397
# Epoch 390/400
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0598 - val_loss: 0.0400
# Epoch 391/400
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0571 - val_loss: 0.0358
# Epoch 392/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0619 - val_loss: 0.0534
# Epoch 393/400
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0588 - val_loss: 0.0402
# Epoch 394/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0572 - val_loss: 0.0480
# Epoch 395/400
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0592 - val_loss: 0.0546
# Epoch 396/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0595 - val_loss: 0.0556
# Epoch 397/400
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0623 - val_loss: 0.0528
# Epoch 398/400
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0585 - val_loss: 0.0474
# Epoch 399/400
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0572 - val_loss: 0.0499
# Epoch 400/400
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0564 - val_loss: 0.0449
# 9/9 [==============================] - 2s 15ms/step

# %%
n_features = 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(train_data.reshape(-1, n_features))

# Inverse scale the data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1))

# Calculate the evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
nmae_test = mae / (np.max(y_test) - np.min(y_test))
mse = mean_squared_error(y_test, y_pred)
nrmse_test = np.sqrt(mse) / (np.max(y_test) - np.min(y_test))

# Calculate the evaluation metrics for training set
y_train_pred = model.predict(X_train)
y_train = y_train.reshape(-1, 1)
y_train_pred = scaler.inverse_transform(y_train_pred.reshape(-1, 1))
mae_train = mean_absolute_error(y_train, y_train_pred)
nmae_train = mae_train / (np.max(y_train) - np.min(y_train))
mse_train = mean_squared_error(y_train, y_train_pred)
nrmse_train = np.sqrt(mse_train) / (np.max(y_train) - np.min(y_train))

# Calculate the average NMAE and NRMSE
nmae_avg = np.mean([nmae_train, nmae_test])
nrmse_avg = np.mean([nrmse_train, nrmse_test])


# Print the evaluation metrics
print("NMAE Train: ", nmae_train)
print("NMAE Test: ", nmae_test)
print("Average NMAE: ", nmae_avg)
print("NRMSE TEST:",nrmse_test)
print("NRMSE Train: ", nrmse_train)
print("Average NMAE: ", nmae_avg)
# Out:
# 28/28 [==============================] - 0s 15ms/step
# NMAE Train:  0.03325712057171421
# NMAE Test:  0.046297720367574215
# Average NMAE:  0.03977742046964421
# NRMSE TEST: 0.058232310107168755
# NRMSE Train:  0.04309387489800257
# Average NMAE:  0.03977742046964421

# %%
# Plot the training and validation losses
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
import seaborn as sns
# Create a heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert the actual and predicted values to a 1D numpy array
y_test = y_test.ravel()
y_pred= y_pred.ravel()

# Define the quarters and years
quarters = ['Q1', 'Q2', 'Q3', 'Q4']
start_year = 1901
end_year = 2016
year_step = 3
years = np.arange(start_year, end_year+1, year_step)

# Create a figure with subplots for each quarter
fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(15, 10), sharex=True)

# Loop through each quarter and plot the actual and predicted values
for i, quarter in enumerate(quarters):
    # Get the indices for the current quarter
    quarter_indices = np.arange(i, len(years)*len(quarters), len(quarters))

    # Plot the actual and predicted values for the current quarter
    axs[i].plot(years, y_test[quarter_indices], label='Actual')
    axs[i].plot(years, y_pred[quarter_indices], label='Predicted')
    axs[i].set_title(f'Quarterly Rainfall ({quarter})')
    axs[i].set_ylabel('Rainfall (mm)')

# Add a legend and x-axis label to the bottom plot
axs[-1].set_xlabel('Year')
axs[-1].legend()

# Adjust the spacing between subplots and save the figure
plt.tight_layout()
plt.savefig('actual_vs_predicted_rainfall.png')
